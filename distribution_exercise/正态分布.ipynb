# %% [markdown]
# 生成并绘制正态分布的概率密度函数（PDF），并且平均值为5，标准差为3。
# 从此分布中生成1000个随机数据。
# 计算这些数据平均值的标准误差。
# 绘制这些数据的直方图。
# 从PDF中计算包含这些数据的95％的间隔。

# %%
import numpy as np
import scipy.stats as st 
# 平均值为5，标准差为3
import matplotlib.pyplot as plt
sample=np.random.normal(5, 3, 1000)

# %%
sample  #从此分布中生成1000个随机数据。
# Out:
# array([ 1.62494014e+00,  4.23687675e+00,  4.24156389e+00,  2.75271025e+00,
#         8.28388042e+00,  5.90186765e+00,  6.28472666e+00,  9.46912500e+00,
#         4.20278239e+00,  6.50791854e+00,  9.04306504e-01,  7.79283945e+00,
#         5.61887809e+00,  1.30704211e+00,  5.08454220e+00,  5.48018351e+00,
#        -3.82355007e-01,  3.06134973e+00,  1.06634866e+01,  4.46591448e+00,
#         3.54790624e+00,  7.25055419e+00, -7.53965236e-01,  1.96522122e+00,
#         5.55624589e+00,  5.36538658e+00,  4.08235910e+00,  1.73495461e+00,
#         6.21798866e+00, -9.09254508e-01,  3.51511487e+00,  1.94487896e+00,
#         3.40212218e+00,  6.24716015e+00,  7.57643513e+00,  7.59472738e+00,
#        -2.16658626e+00,  5.32369788e+00,  6.29555395e+00,  1.03679189e+01,
#         2.96299903e+00,  5.49278041e+00,  3.17258136e+00,  6.22681398e+00,
#         9.77361730e+00,  1.03260404e+01,  8.97050203e+00,  3.19355299e+00,
# ...

# %%
# 计算这些数据平均值的标准误差。

# %%
plt. hist(sample, bins=100, alpha=0.3,density=True,label="sample") #绘制这些数据的直方图。柱数100,透明度0.3
plt.show()
